# %% [markdown]
# # NumPy Tricks

# %% [markdown]
# ## n.sort()

# %%
import numpy as np

a = np.random.randint(1,100,15)
a
# Out:
# array([ 4, 32, 63, 21, 59, 32, 70, 15, 81, 10, 70, 14, 35, 13, 36],
#       dtype=int32)

# %%
b = np.random.randint(1,100,24).reshape(6,4)
b
# Out:
# array([[46, 33, 48, 29],
#        [34, 90, 86, 52],
#        [83, 28, 47, 83],
#        [55, 27, 21, 98],
#        [58, 84, 76, 87],
#        [75, 98, 76, 15]], dtype=int32)
